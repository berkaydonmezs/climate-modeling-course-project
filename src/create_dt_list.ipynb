# %%
import datetime as dt
import pandas as pd

# %%
dt_list = pd.date_range(dt.datetime(2008,3,1,0), periods=1585, freq='6H').tolist()

# %%
dt_list_str = [d.strftime('%Y%m%d%H') for d in dt_list]

# %%
dt_list_str
# Out:
# ['2008030100',
#  '2008030106',
#  '2008030112',
#  '2008030118',
#  '2008030200',
#  '2008030206',
#  '2008030212',
#  '2008030218',
#  '2008030300',
#  '2008030306',
#  '2008030312',
#  '2008030318',
#  '2008030400',
#  '2008030406',
#  '2008030412',
#  '2008030418',
#  '2008030500',
#  '2008030506',
#  '2008030512',
#  '2008030518',
#  '2008030600',
#  '2008030606',
#  '2008030612',
#  '2008030618',
#  '2008030700',
#  '2008030706',
#  '2008030712',
#  '2008030718',
#  '2008030800',
#  '2008030806',
#  '2008030812',
#  '2008030818',
#  '2008030900',
#  '2008030906',
#  '2008030912',
#  '2008030918',
#  '2008031000',
#  '2008031006',
#  '2008031012',
#  '2008031018',
#  '2008031100',
#  '2008031106',
#  '2008031112',
#  '2008031118',
#  '2008031200',
#  '2008031206',
#  '2008031212',
#  '2008031218',
#  '2008031300',
#  '2008031306',
#  '2008031312',
#  '2008031318',
#  '2008031400',
#  '2008031406',
#  '2008031412',
#  '2008031418',
#  '2008031500',
#  '2008031506',
# ...
